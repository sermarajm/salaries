# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("salaries.csv")
data
# Out:
#         work_year experience_level employment_type  \
# 0            2025               MI              FT
# 1            2025               MI              FT
# 2            2025               SE              FT
# 3            2025               SE              FT
# 4            2025               SE              FT
# ...           ...              ...             ...
# 145409       2020               SE              FT
# 145410       2021               MI              FT
# 145411       2020               EN              FT
# 145412       2020               EN              CT
# 145413       2021               SE              FT
#
#                              job_title   salary salary_currency  \
# 0                        Data Engineer    49200             EUR
# 1                        Data Engineer    28800             EUR
# 2                   Software Developer   216000             USD
# 3                   Software Developer   135000             USD
# ...

# %%
data.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2025               MI              FT                   Data Engineer
# 1       2025               MI              FT                   Data Engineer
# 2       2025               SE              FT              Software Developer
# 3       2025               SE              FT              Software Developer
# 4       2025               SE              FT  Business Intelligence Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   49200             EUR          51789                 SK             0
# 1   28800             EUR          30315                 SK             0
# 2  216000             USD         216000                 US             0
# 3  135000             USD         135000                 US             0
# 4  182300             USD         182300                 US             0
#
#   company_location company_size
# ...

# %%
data.tail()
# Out:
#         work_year experience_level employment_type                 job_title  \
# 145409       2020               SE              FT            Data Scientist
# 145410       2021               MI              FT  Principal Data Scientist
# 145411       2020               EN              FT            Data Scientist
# 145412       2020               EN              CT     Business Data Analyst
# 145413       2021               SE              FT            Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 145409   412000             USD         412000                 US
# 145410   151000             USD         151000                 US
# 145411   105000             USD         105000                 US
# 145412   100000             USD         100000                 US
# 145413  7000000             INR          94665                 IN
#
#         remote_ratio company_location company_size
# 145409           100               US            L
# ...

# %%
data.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  145414.000000  1.454140e+05  145414.000000  145414.000000
# mean     2024.411893  1.628851e+05  157498.113242      20.896888
# std         0.675514  2.106602e+05   74141.921537      40.587943
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060000e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146100.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145414 entries, 0 to 145413
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           145414 non-null  int64
#  1   experience_level    145414 non-null  object
#  2   employment_type     145414 non-null  object
#  3   job_title           145414 non-null  object
#  4   salary              145414 non-null  int64
#  5   salary_currency     145414 non-null  object
#  6   salary_in_usd       145414 non-null  int64
#  7   employee_residence  145414 non-null  object
#  8   remote_ratio        145414 non-null  int64
#  9   company_location    145414 non-null  object
#  10  company_size        145414 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 12.2+ MB

# %%
data.isnull()
# Out:
#         work_year  experience_level  employment_type  job_title  salary  \
# 0           False             False            False      False   False
# 1           False             False            False      False   False
# 2           False             False            False      False   False
# 3           False             False            False      False   False
# 4           False             False            False      False   False
# ...           ...               ...              ...        ...     ...
# 145409      False             False            False      False   False
# 145410      False             False            False      False   False
# 145411      False             False            False      False   False
# 145412      False             False            False      False   False
# 145413      False             False            False      False   False
#
#         salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
data
# Out:
#         work_year experience_level employment_type  \
# 0            2025               MI              FT
# 1            2025               MI              FT
# 2            2025               SE              FT
# 3            2025               SE              FT
# 4            2025               SE              FT
# ...           ...              ...             ...
# 145409       2020               SE              FT
# 145410       2021               MI              FT
# 145411       2020               EN              FT
# 145412       2020               EN              CT
# 145413       2021               SE              FT
#
#                              job_title   salary salary_currency  \
# 0                        Data Engineer    49200             EUR
# 1                        Data Engineer    28800             EUR
# 2                   Software Developer   216000             USD
# 3                   Software Developer   135000             USD
# ...

# %%
experience_level ,employment_type,job_title,employee_residence ,company_location  company_size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145414 entries, 0 to 145413
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           145414 non-null  int64
#  1   experience_level    145414 non-null  object
#  2   employment_type     145414 non-null  object
#  3   job_title           145414 non-null  object
#  4   salary              145414 non-null  int64
#  5   salary_currency     145414 non-null  object
#  6   salary_in_usd       145414 non-null  int64
#  7   employee_residence  145414 non-null  object
#  8   remote_ratio        145414 non-null  int64
#  9   company_location    145414 non-null  object
#  10  company_size        145414 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 12.2+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
data["experience_level"]=label_encoder.fit_transform(data["experience_level"])
data["job_title"]=label_encoder.fit_transform(data["job_title"])
data["employment_type"]=label_encoder.fit_transform(data["employment_type"])
data["salary_currency"]=label_encoder.fit_transform(data["salary_currency"])
data["employee_residence"]=label_encoder.fit_transform(data["employee_residence"])
data["company_location"]=label_encoder.fit_transform(data["company_location"])
data["company_size"]=label_encoder.fit_transform(data["company_size"])
data
# Out:
#         work_year  experience_level  employment_type  job_title   salary  \
# 0            2025                 2                2        139    49200
# 1            2025                 2                2        139    28800
# 2            2025                 3                2        382   216000
# 3            2025                 3                2        382   135000
# 4            2025                 3                2         86   182300
# ...           ...               ...              ...        ...      ...
# 145409       2020                 3                2        198   412000
# 145410       2021                 2                2        329   151000
# 145411       2020                 0                2        198   105000
# 145412       2020                 0                0         77   100000
# 145413       2021                 3                2        198  7000000
#
#         salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145414 entries, 0 to 145413
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           145414 non-null  int64
#  1   experience_level    145414 non-null  int32
#  2   employment_type     145414 non-null  int32
#  3   job_title           145414 non-null  int32
#  4   salary              145414 non-null  int64
#  5   salary_currency     145414 non-null  int32
#  6   salary_in_usd       145414 non-null  int64
#  7   employee_residence  145414 non-null  int32
#  8   remote_ratio        145414 non-null  int64
#  9   company_location    145414 non-null  int32
#  10  company_size        145414 non-null  int32
# dtypes: int32(7), int64(4)
# memory usage: 8.3 MB

# %%
correlation=data.corr()
correlation
# Out:
#                     work_year  experience_level  employment_type  job_title  \
# work_year            1.000000         -0.027624        -0.007136   0.056432
# experience_level    -0.027624          1.000000         0.000546   0.136696
# employment_type     -0.007136          0.000546         1.000000   0.011711
# job_title            0.056432          0.136696         0.011711   1.000000
# salary              -0.013792          0.089263        -0.011210   0.083023
# salary_currency      0.019763          0.104338         0.007056   0.059296
# salary_in_usd        0.016774          0.271123         0.012672   0.257656
# employee_residence   0.002255          0.081270         0.017466   0.044654
# remote_ratio        -0.076217          0.071179        -0.028099  -0.063562
# company_location     0.000187          0.080219         0.016918   0.043444
# company_size         0.067024          0.010660        -0.009940   0.064596
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
sns.heatmap(correlation,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':7},cmap='Blues')
# Out:
# <Axes: >

# %%
x=data.drop(['employment_type','company_size','salary','company_location'],axis=1)
y=data['company_size']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=60)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\serma\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_test
# Out:
# 467       1
# 13823     1
# 111672    1
# 68844     1
# 122421    1
#          ..
# 31269     1
# 84401     1
# 90762     1
# 41340     0
# 102493    1
# Name: company_size, Length: 29083, dtype: int32

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm,annot=True, fmt='d', cmap="Blues", cbar=False)
plt.xlabel('Predicted Lables')
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
import joblib
joblib.dump(model,'company_size.pk1')
# Out:
# ['company_size.pk1']

# %%
import joblib
out={0:"Nil",1:"Small",2: "Big"}
loaded_model=joblib.load("company_size.pk1")
y_pred=loaded_model.predict([[2020,0,198,24,105000,97,100]])
y_pred[0]
predicted_label = out.get(y_pred[0], "Unknown")
print("Predicted Output:", predicted_label)
# Out:
# Predicted Output: Small
# C:\Users\serma\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
data.tail()
# Out:
#         work_year  experience_level  employment_type  job_title   salary  \
# 145409       2020                 3                2        198   412000
# 145410       2021                 2                2        329   151000
# 145411       2020                 0                2        198   105000
# 145412       2020                 0                0         77   100000
# 145413       2021                 3                2        198  7000000
#
#         salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 145409               24         412000                  97           100
# 145410               24         151000                  97           100
# 145411               24         105000                  97           100
# 145412               24         100000                  97           100
# 145413               12          94665                  45            50
#
#         company_location  company_size
# 145409                91             0
# ...
